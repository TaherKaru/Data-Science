# %% [markdown]
# # How to read csv files

# %%
import pandas as pd
df = pd.read_csv('ai_student_impact_dataset (1).csv')
display(df)
# Out:
#        Student_ID Major_Category  ... Skill_Retention_Score  \
# 0          100001     Humanities  ...                 86.44
# 1          100002        Medical  ...                 69.39
# 2          100003       Business  ...                 73.93
# 3          100004       Business  ...                 63.58
# 4          100005           STEM  ...                100.00
# ...           ...            ...  ...                   ...
# 49995      149996       Business  ...                 66.16
# 49996      149997           STEM  ...                 81.62
# 49997      149998       Business  ...                 97.21
# 49998      149999       Business  ...                 84.12
# 49999      150000           Arts  ...                 76.16
#
#        Burnout_Risk_Level
# 0                    High
# 1                     Low
# 2                  Medium
# 3                  Medium
# 4                  Medium
# ...                   ...
# 49995                High
# ...

# %% [markdown]
# # Attributes to understand the data

# %%
df.shape # --> gives info about the rows and columns only
# Out:
# (50000, 16)

# %%
df.info() # --> gives info of rows and column as well as data types of the column
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 16 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Student_ID                  50000 non-null  int64
#  1   Major_Category              50000 non-null  str
#  2   Year_of_Study               50000 non-null  str
#  3   Pre_Semester_GPA            50000 non-null  float64
#  4   Weekly_GenAI_Hours          50000 non-null  float64
#  5   Primary_Use_Case            50000 non-null  str
#  6   Prompt_Engineering_Skill    50000 non-null  str
#  7   Tool_Diversity              50000 non-null  int64
#  8   Paid_Subscription           50000 non-null  bool
#  9   Traditional_Study_Hours     50000 non-null  float64
#  10  Perceived_AI_Dependency     50000 non-null  int64
#  11  Institutional_Policy        50000 non-null  str
#  12  Anxiety_Level_During_Exams  50000 non-null  int64
# ...

# %%
pd.set_option('display.max_columns',4) # --> changes the setting of jupiter to display number of column we want to see!!
# Out:
# None

# %%
df.head(10) # --> Gives fist 10 rows of the data
# Out:
#    Student_ID Major_Category  ... Skill_Retention_Score  Burnout_Risk_Level
# 0      100001     Humanities  ...                 86.44                High
# 1      100002        Medical  ...                 69.39                 Low
# 2      100003       Business  ...                 73.93              Medium
# 3      100004       Business  ...                 63.58              Medium
# 4      100005           STEM  ...                100.00              Medium
# 5      100006           STEM  ...                 65.92                High
# 6      100007           STEM  ...                 67.97              Medium
# 7      100008           Arts  ...                 85.09              Medium
# 8      100009       Business  ...                 55.71              Medium
# 9      100010       Business  ...                 87.18                High
#
# [10 rows x 16 columns]

# %%
df.tail(10) # --> Gives last 10 rows of the data
# Out:
#        Student_ID Major_Category  ... Skill_Retention_Score  \
# 49990      149991       Business  ...                 84.87
# 49991      149992     Humanities  ...                 65.24
# 49992      149993       Business  ...                 84.04
# 49993      149994           STEM  ...                 58.44
# 49994      149995     Humanities  ...                 74.76
# 49995      149996       Business  ...                 66.16
# 49996      149997           STEM  ...                 81.62
# 49997      149998       Business  ...                 97.21
# 49998      149999       Business  ...                 84.12
# 49999      150000           Arts  ...                 76.16
#
#        Burnout_Risk_Level
# 49990              Medium
# 49991                High
# 49992                 Low
# 49993                High
# 49994                High
# 49995                High
# 49996              Medium
# 49997                High
# 49998              Medium
# 49999                 Low
#
# ...

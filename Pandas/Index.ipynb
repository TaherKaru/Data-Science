# %% [markdown]
# # Index in Pandas

# %%
import pandas as pd
df = pd.read_csv("ai_student_impact_dataset (1).csv")
df
# Out:
#        Student_ID Major_Category Year_of_Study  Pre_Semester_GPA  \
# 0          100001     Humanities        Senior             2.418
# 1          100002        Medical        Junior             3.821
# 2          100003       Business      Freshman             3.398
# 3          100004       Business        Senior             3.789
# 4          100005           STEM     Sophomore             3.635
# ...           ...            ...           ...               ...
# 49995      149996       Business        Senior             2.899
# 49996      149997           STEM        Senior             2.870
# 49997      149998       Business        Senior             3.177
# 49998      149999       Business        Junior             3.398
# 49999      150000           Arts     Sophomore             3.242
#
#        Weekly_GenAI_Hours           Primary_Use_Case Prompt_Engineering_Skill  \
# 0                   23.31       Copywriting/Drafting                 Beginner
# ...

# %%
df.set_index('Student_ID')  # --> The Student_ID becomes the index label for rows
# Out:
#            Major_Category Year_of_Study  Pre_Semester_GPA  Weekly_GenAI_Hours  \
# Student_ID
# 100001         Humanities        Senior             2.418               23.31
# 100002            Medical        Junior             3.821                1.12
# 100003           Business      Freshman             3.398               21.26
# 100004           Business        Senior             3.789                1.82
# 100005               STEM     Sophomore             3.635                9.29
# ...                   ...           ...               ...                 ...
# 149996           Business        Senior             2.899               12.16
# 149997               STEM        Senior             2.870                2.51
# 149998           Business        Senior             3.177               15.87
# 149999           Business        Junior             3.398               19.91
# 150000               Arts     Sophomore             3.242                3.30
#
# ...

# %%
df.reset_index() # --> reset the index to initial place
# Out:
#        Student_ID Major_Category Year_of_Study  Pre_Semester_GPA  \
# 0          100001     Humanities        Senior             2.418
# 1          100002        Medical        Junior             3.821
# 2          100003       Business      Freshman             3.398
# 3          100004       Business        Senior             3.789
# 4          100005           STEM     Sophomore             3.635
# ...           ...            ...           ...               ...
# 49995      149996       Business        Senior             2.899
# 49996      149997           STEM        Senior             2.870
# 49997      149998       Business        Senior             3.177
# 49998      149999       Business        Junior             3.398
# 49999      150000           Arts     Sophomore             3.242
#
#        Weekly_GenAI_Hours           Primary_Use_Case Prompt_Engineering_Skill  \
# 0                   23.31       Copywriting/Drafting                 Beginner
# ...

# %% [markdown]
# # Sorting the index

# %%
df.sort_index(ascending=False) # --> sort index alphabettically in decending order
# Out:
#            Major_Category Year_of_Study  Pre_Semester_GPA  Weekly_GenAI_Hours  \
# Student_ID
# 150000               Arts     Sophomore             3.242                3.30
# 149999           Business        Junior             3.398               19.91
# 149998           Business        Senior             3.177               15.87
# 149997               STEM        Senior             2.870                2.51
# 149996           Business        Senior             2.899               12.16
# ...                   ...           ...               ...                 ...
# 100005               STEM     Sophomore             3.635                9.29
# 100004           Business        Senior             3.789                1.82
# 100003           Business      Freshman             3.398               21.26
# 100002            Medical        Junior             3.821                1.12
# 100001         Humanities        Senior             2.418               23.31
#
# ...

# %% [markdown]
# # Columns property

# %%
import pandas as pd 
df = pd.read_csv('ai_student_impact_dataset (1).csv')
display(df)
# Out:
#        Student_ID Major_Category Year_of_Study  Pre_Semester_GPA  \
# 0          100001     Humanities        Senior             2.418
# 1          100002        Medical        Junior             3.821
# 2          100003       Business      Freshman             3.398
# 3          100004       Business        Senior             3.789
# 4          100005           STEM     Sophomore             3.635
# ...           ...            ...           ...               ...
# 49995      149996       Business        Senior             2.899
# 49996      149997           STEM        Senior             2.870
# 49997      149998       Business        Senior             3.177
# 49998      149999       Business        Junior             3.398
# 49999      150000           Arts     Sophomore             3.242
#
#        Weekly_GenAI_Hours           Primary_Use_Case Prompt_Engineering_Skill  \
# 0                   23.31       Copywriting/Drafting                 Beginner
# ...

# %%
df.columns
# Out:
# Index(['Student_ID', 'Major_Category', 'Year_of_Study', 'Pre_Semester_GPA',
#        'Weekly_GenAI_Hours', 'Primary_Use_Case', 'Prompt_Engineering_Skill',
#        'Tool_Diversity', 'Paid_Subscription', 'Traditional_Study_Hours',
#        'Perceived_AI_Dependency', 'Institutional_Policy',
#        'Anxiety_Level_During_Exams', 'Post_Semester_GPA',
#        'Skill_Retention_Score', 'Burnout_Risk_Level'],
#       dtype='str')

# %%
df.columns[0]
# Out:
# 'Student_ID'

# %%
df.columns[0:10]
# Out:
# Index(['Student_ID', 'Major_Category', 'Year_of_Study', 'Pre_Semester_GPA',
#        'Weekly_GenAI_Hours', 'Primary_Use_Case', 'Prompt_Engineering_Skill',
#        'Tool_Diversity', 'Paid_Subscription', 'Traditional_Study_Hours'],
#       dtype='str')

# %%
df.columns.shape
# Out:
# (16,)

# %%
df['Student_ID']
# Out:
# 0        100001
# 1        100002
# 2        100003
# 3        100004
# 4        100005
#           ...
# 49995    149996
# 49996    149997
# 49997    149998
# 49998    149999
# 49999    150000
# Name: Student_ID, Length: 50000, dtype: int64

# %%
df[['Student_ID', 'Major_Category']]
# Out:
#        Student_ID Major_Category
# 0          100001     Humanities
# 1          100002        Medical
# 2          100003       Business
# 3          100004       Business
# 4          100005           STEM
# ...           ...            ...
# 49995      149996       Business
# 49996      149997           STEM
# 49997      149998       Business
# 49998      149999       Business
# 49999      150000           Arts
#
# [50000 rows x 2 columns]

# %% [markdown]
# # loc and iloc

# %%
df.loc[0:100,["Student_ID",'Major_Category', 'Year_of_Study']] # --> Takes input as Label base
# Out:
#      Student_ID Major_Category Year_of_Study
# 0        100001     Humanities        Senior
# 1        100002        Medical        Junior
# 2        100003       Business      Freshman
# 3        100004       Business        Senior
# 4        100005           STEM     Sophomore
# ..          ...            ...           ...
# 96       100097       Business      Freshman
# 97       100098     Humanities      Graduate
# 98       100099           STEM      Freshman
# 99       100100           STEM      Graduate
# 100      100101           STEM     Sophomore
#
# [101 rows x 3 columns]

# %%
df.loc[0:2]
# Out:
#    Student_ID Major_Category Year_of_Study  Pre_Semester_GPA  \
# 0      100001     Humanities        Senior             2.418
# 1      100002        Medical        Junior             3.821
# 2      100003       Business      Freshman             3.398
#
#    Weekly_GenAI_Hours      Primary_Use_Case Prompt_Engineering_Skill  \
# 0               23.31  Copywriting/Drafting                 Beginner
# 1                1.12              Ideation                 Advanced
# 2               21.26   Summarizing_Reading                 Beginner
#
#    Tool_Diversity  Paid_Subscription  Traditional_Study_Hours  \
# 0               1               True                     8.13
# 1               5              False                    16.65
# 2               2              False                    10.35
#
#    Perceived_AI_Dependency   Institutional_Policy  Anxiety_Level_During_Exams  \
# 0                        5  Allowed_With_Citation                           6
# ...

# %%
df.loc[0]
# Out:
# Student_ID                                   100001
# Major_Category                           Humanities
# Year_of_Study                                Senior
# Pre_Semester_GPA                              2.418
# Weekly_GenAI_Hours                            23.31
# Primary_Use_Case               Copywriting/Drafting
# Prompt_Engineering_Skill                   Beginner
# Tool_Diversity                                    1
# Paid_Subscription                              True
# Traditional_Study_Hours                        8.13
# Perceived_AI_Dependency                           5
# Institutional_Policy          Allowed_With_Citation
# Anxiety_Level_During_Exams                        6
# Post_Semester_GPA                             2.393
# Skill_Retention_Score                         86.44
# Burnout_Risk_Level                             High
# Name: 0, dtype: object

# %%
df.iloc[0:100,2:4] # --> Take input as integer based
# Out:
#    Year_of_Study  Pre_Semester_GPA
# 0         Senior             2.418
# 1         Junior             3.821
# 2       Freshman             3.398
# 3         Senior             3.789
# 4      Sophomore             3.635
# ..           ...               ...
# 95        Senior             3.773
# 96      Freshman             2.907
# 97      Graduate             2.292
# 98      Freshman             2.016
# 99      Graduate             2.661
#
# [100 rows x 2 columns]

# %%
df.iloc[0]
# Out:
# Student_ID                                   100001
# Major_Category                           Humanities
# Year_of_Study                                Senior
# Pre_Semester_GPA                              2.418
# Weekly_GenAI_Hours                            23.31
# Primary_Use_Case               Copywriting/Drafting
# Prompt_Engineering_Skill                   Beginner
# Tool_Diversity                                    1
# Paid_Subscription                              True
# Traditional_Study_Hours                        8.13
# Perceived_AI_Dependency                           5
# Institutional_Policy          Allowed_With_Citation
# Anxiety_Level_During_Exams                        6
# Post_Semester_GPA                             2.393
# Skill_Retention_Score                         86.44
# Burnout_Risk_Level                             High
# Name: 0, dtype: object
